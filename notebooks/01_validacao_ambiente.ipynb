# %%
import sys
import pandas as pd
import numpy as np
import sklearn
import plotly
import geopandas as gpd
import duckdb

print(f"Versão do Python: {sys.version}")
print(f"Pandas: {pd.__version__}")
print(f"NumPy: {np.__version__}")
print(f"Scikit-learn: {sklearn.__version__}")
print(f"Plotly: {plotly.__version__}")
print(f"GeoPandas: {gpd.__version__}")
print(f"DuckDB: {duckdb.__version__}")
# Out:
# Versão do Python: 3.12.7 | packaged by Anaconda, Inc. | (main, Oct  4 2024, 13:27:36) [GCC 11.2.0]
# Pandas: 3.0.5
# NumPy: 2.5.2
# Scikit-learn: 1.9.0
# Plotly: 7.0.0
# GeoPandas: 1.1.4
# DuckDB: 1.5.5

# %%
import pandas as pd

dados_teste = pd.DataFrame({
    "municipio": ["Guariba", "Jaboticabal", "Sertãozinho"],
    "area_colhida_ha": [12000, 18000, 22000],
    "producao_ton": [960000, 1440000, 1760000]
})

dados_teste["produtividade_ton_ha"] = (
    dados_teste["producao_ton"] / dados_teste["area_colhida_ha"]
)

dados_teste
# Out:
#      municipio  area_colhida_ha  producao_ton  produtividade_ton_ha
# 0      Guariba            12000        960000                  80.0
# 1  Jaboticabal            18000       1440000                  80.0
# 2  Sertãozinho            22000       1760000                  80.0
